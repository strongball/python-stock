# %%
import pandas as pd
import glob

path = './TasiResult'
all_files = glob.glob(path + "/*.json")
li = []
for filename in all_files:
    df = pd.read_json(filename)
    li.append(df)
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame2016 = frame[frame['year']==2016]

# %%
import matplotlib.pyplot as plt
def heatmap(df):
    df.plot.scatter(x='cold', y='rate', c='p', colormap='viridis')

# %%
heatmap(frame[frame['year']==2019])
